# %% [markdown]
# # Cost of living per country

# %%
# import libraries
import pandas as pd

# %% [markdown]
# ### CSV 2 we'll use

# %%
cost_living = pd.read_csv('cost-of-living.csv')

# %%
cost_living.head()
# Out:
#                                           Unnamed: 0  \
# 0                       Meal, Inexpensive Restaurant
# 1  Meal for 2 People, Mid-range Restaurant, Three...
# 2     McMeal at McDonalds (or Equivalent Combo Meal)
# 3                  Domestic Beer (0.5 liter draught)
# 4                  Imported Beer (0.33 liter bottle)
#
#    Saint Petersburg, Russia  Istanbul, Turkey  Izmir, Turkey  \
# 0                      7.34              4.58           3.06
# 1                     29.35             15.28          12.22
# 2                      4.40              3.82           3.06
# 3                      2.20              3.06           2.29
# 4                      2.20              3.06           2.75
#
#    Helsinki, Finland  Chisinau, Moldova  Milan, Italy  Cairo, Egypt  \
# 0              12.00               4.67          15.0          3.38
# 1              65.00              20.74          60.0         17.48
# ...

# %%
cost_living["Category"]="Grocery"

# %%
# Rename Categories in Categry column

# Restaurant
cost_living.loc[(cost_living["Unnamed: 0"] == "Meal, Inexpensive Restaurant") | 
                (cost_living["Unnamed: 0"] == "Meal for 2 People, Mid-range Restaurant, Three-course") |
                (cost_living["Unnamed: 0"] == "McMeal at McDonalds (or Equivalent Combo Meal)")
                , "Category"] = "Restaurant"
# Drink
cost_living.loc[(cost_living["Unnamed: 0"] == "Domestic Beer (0.5 liter draught)") | 
                (cost_living["Unnamed: 0"] == "Imported Beer (0.33 liter bottle)") |
                (cost_living["Unnamed: 0"] == "Coke/Pepsi (0.33 liter bottle)")|
                (cost_living["Unnamed: 0"] == "Water (0.33 liter bottle)")|
                (cost_living["Unnamed: 0"] == "Milk (regular), (1 liter)")|
                (cost_living["Unnamed: 0"] == "Water (1.5 liter bottle)")|
                (cost_living["Unnamed: 0"] == "Bottle of Wine (Mid-Range)")|
                (cost_living["Unnamed: 0"] == "Domestic Beer (0.5 liter bottle)")|
                (cost_living["Unnamed: 0"] == "Imported Beer (0.33 liter bottle)")|
                (cost_living["Unnamed: 0"] == "Cappuccino (regular)")
                , "Category"] = "Drink"

# Cigarettes
cost_living.loc[(cost_living["Unnamed: 0"] == "Cigarettes 20 Pack (Marlboro)")
                , "Category"] = "Cigarettes"

# Public Transport
cost_living.loc[(cost_living["Unnamed: 0"] == "One-way Ticket (Local Transport)") | 
                (cost_living["Unnamed: 0"] == "Monthly Pass (Regular Price)") |
                (cost_living["Unnamed: 0"] == "Taxi Start (Normal Tariff)") |
                (cost_living["Unnamed: 0"] == "Taxi 1km (Normal Tariff)") |
                (cost_living["Unnamed: 0"] == "Taxi 1hour Waiting (Normal Tariff)")
                , "Category"] = "Public Transport"

# Private Transport
cost_living.loc[(cost_living["Unnamed: 0"] == "Gasoline (1 liter)") | 
                (cost_living["Unnamed: 0"] == "Volkswagen Golf") |
                (cost_living["Unnamed: 0"] == "Toyota Corolla 1.6l 97kW Comfort (Or Equivalent New Car)")
                , "Category"] = "Private Transport"

# Apartment Rent
cost_living.loc[(cost_living["Unnamed: 0"] == "Apartment (1 bedroom) in City Centre") | 
                (cost_living["Unnamed: 0"] == "Apartment (1 bedroom) Outside of Centre") |
                (cost_living["Unnamed: 0"] == "Apartment (3 bedrooms) in City Centre")|
                (cost_living["Unnamed: 0"] == "Apartment (3 bedrooms) Outside of Centre")
                , "Category"] = "Apartment Rent"

# Household Expense
cost_living.loc[(cost_living["Unnamed: 0"] == "Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment")
                , "Category"] = "Household Expense"

# Phone
cost_living.loc[(cost_living["Unnamed: 0"] == "Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment")
                , "Category"] = "Phone"

# Fitness
cost_living.loc[(cost_living["Unnamed: 0"] == "Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment")
                , "Category"] = "Fitness"

# Activity
cost_living.loc[(cost_living["Unnamed: 0"] == "Tennis Court Rent (1 Hour on Weekend)")|
                (cost_living["Unnamed: 0"] == "Cinema, International Release, 1 Seat")
                , "Category"] = "Activity"

# Phone&Internet
cost_living.loc[(cost_living["Unnamed: 0"] == "1 min. of Prepaid Mobile Tariff Local (No Discounts or Plans)")|
                (cost_living["Unnamed: 0"] == "Internet (60 Mbps or More, Unlimited Data, Cable/ADSL)")
                , "Category"] = "Phone&Internet"

# School
cost_living.loc[(cost_living["Unnamed: 0"] == "Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child")|
                (cost_living["Unnamed: 0"] == "International Primary School, Yearly for 1 Child   ")
                , "Category"] = "School"

# Apartment Sale Price
cost_living.loc[(cost_living["Unnamed: 0"] == "Price per Square Meter to Buy Apartment Outside of Centre") | 
                (cost_living["Unnamed: 0"] == "Price per Square Meter to Buy Apartment in City Centre")
                , "Category"] = "Apartment Sale Price"

# Mortgage Interest Rate
cost_living.loc[(cost_living["Unnamed: 0"] == "Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate")
                , "Category"] = "Mortgage Interest Rate"

# Net Salary
cost_living.loc[(cost_living["Unnamed: 0"] == "Average Monthly Net Salary (After Tax)")
                , "Category"] = "Net Salary"

# Clothe
cost_living.loc[(cost_living["Unnamed: 0"] == "1 Pair of Jeans (Levis 501 Or Similar)") | 
                (cost_living["Unnamed: 0"] == "1 Summer Dress in a Chain Store (Zara, H&M, ...)") |
                (cost_living["Unnamed: 0"] == "1 Pair of Nike Running Shoes (Mid-Range)")|
                (cost_living["Unnamed: 0"] == "1 Pair of Men Leather Business Shoes")
                , "Category"] = "Clothe"

# %%
cost_living["Category"]
# Out:
# 0                 Restaurant
# 1                 Restaurant
# 2                 Restaurant
# 3                      Drink
# 4                      Drink
# 5                      Drink
# 6                    Grocery
# 7                      Drink
# 8                    Grocery
# 9                    Grocery
# 10                   Grocery
# 11                     Drink
# 12                     Drink
# 13                     Drink
# 14                     Drink
# 15                Cigarettes
# 16          Public Transport
# 17                   Grocery
# 18          Public Transport
# 19         Private Transport
# 20         Private Transport
# 21            Apartment Rent
# 22            Apartment Rent
# 23            Apartment Rent
# 24            Apartment Rent
# 25                   Fitness
# 26            Phone&Internet
# 27            Phone&Internet
# 28                   Grocery
# 29                  Activity
# 30                  Activity
# 31                    Clothe
# ...

# %%
cost_living
# Out:
#                                            Unnamed: 0  \
# 0                        Meal, Inexpensive Restaurant
# 1   Meal for 2 People, Mid-range Restaurant, Three...
# 2      McMeal at McDonalds (or Equivalent Combo Meal)
# 3                   Domestic Beer (0.5 liter draught)
# 4                   Imported Beer (0.33 liter bottle)
# 5                      Coke/Pepsi (0.33 liter bottle)
# 6                          Water (0.33 liter bottle)
# 7                           Milk (regular), (1 liter)
# 8                    Loaf of Fresh White Bread (500g)
# 9                                 Eggs (regular) (12)
# 10                                 Local Cheese (1kg)
# 11                           Water (1.5 liter bottle)
# 12                         Bottle of Wine (Mid-Range)
# 13                   Domestic Beer (0.5 liter bottle)
# 14                  Imported Beer (0.33 liter bottle)
# 15                      Cigarettes 20 Pack (Marlboro)
# ...

# %%
cost_living.groupby("Category").mean()
# Out:
#                         Saint Petersburg, Russia  Istanbul, Turkey  \
# Category
# Activity                               11.735000          9.740000
# Apartment Rent                        624.110000        332.437500
# Apartment Sale Price                 1991.875000        986.115000
# Cigarettes                              2.200000          2.750000
# Clothe                                 71.427500         43.487500
# Drink                                   1.930000          2.394444
# Fitness                               102.170000         59.330000
# Grocery                               340.278125        434.927500
# Mortgage Interest Rate                 10.290000         19.080000
# Net Salary                            645.940000        436.000000
# Phone&Internet                          3.495000          7.155000
# Private Transport                   12865.116667      15106.306667
# Public Transport                        9.856000          7.310000
# ...

# %%
# save new csv as cost_living_clean
cost_living.to_csv('cost_living_category.csv')

# %% [markdown]
# ### CSV 2 we'll use

# %%
# open csv & # transforme data so we have the rows as cities(location)
cost_living_clean = pd.read_csv('cost-of-living.csv', index_col=[0]).T.reset_index()

# %%
cost_living_clean
# Out:
#                         index  Meal, Inexpensive Restaurant  \
# 0    Saint Petersburg, Russia                          7.34
# 1            Istanbul, Turkey                          4.58
# 2               Izmir, Turkey                          3.06
# 3           Helsinki, Finland                         12.00
# 4           Chisinau, Moldova                          4.67
# ..                        ...                           ...
# 155      Melbourne, Australia                         10.22
# 156          Perth, Australia                         12.43
# 157         Sydney, Australia                         11.81
# 158         Alexandria, Egypt                          2.81
# 159            Quito, Ecuador                          3.59
#
#      Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                                29.35
# 1                                                15.28
# 2                                                12.22
# ...

# %%
# data needs to be transformed so we have the rows are cities.
cost_living_clean = cost_living_clean.rename(columns={'index':'location'})
cost_living_clean.head()
# Out:
#                    location  Meal, Inexpensive Restaurant  \
# 0  Saint Petersburg, Russia                          7.34
# 1          Istanbul, Turkey                          4.58
# 2             Izmir, Turkey                          3.06
# 3         Helsinki, Finland                         12.00
# 4         Chisinau, Moldova                          4.67
#
#    Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                              29.35
# 1                                              15.28
# 2                                              12.22
# 3                                              65.00
# 4                                              20.74
#
#    McMeal at McDonalds (or Equivalent Combo Meal)  \
# 0                                            4.40
# 1                                            3.82
# 2                                            3.06
# 3                                            8.00
# ...

# %%
# separamos de la columna location Country y City
cost_living_clean["Country"]=cost_living_clean["location"].str.split(",").str[-1]

# %%
cost_living_clean["City"]=cost_living_clean["location"].str.split(",").str[0]

# %%
# save new csv as cost_living_clean
cost_living_clean.to_csv('cost_living_clean.csv')
